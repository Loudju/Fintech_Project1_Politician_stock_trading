# %%
import requests
import json
import pandas as pd
import hvplot.pandas
import quiverquant
from datetime import datetime
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# %%
quiver = quiverquant.quiver("c28eacfdf71675aa0dcad7feaa75eedfff51c547")
senate_party_df = quiver.senate_trading()
senate_party_df
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 0     ABYIX 2022-05-23  Carper, Thomas R.    Purchase   1001.0     D
# 1     GSMYX 2022-05-16  Carper, Thomas R.        Sale   1001.0     D
# 2       JCI 2022-05-16  Carper, Thomas R.        Sale   1001.0     D
# 3     FCPIX 2022-05-16  Carper, Thomas R.        Sale   1001.0     D
# 4       IRT 2022-05-05        Thune, John        Sale  15001.0
# ...     ...        ...                ...         ...      ...   ...
# 2571     GD 2020-01-04      Boozman, John        Sale   1001.0     R
# 2572   FBHS 2020-01-03      Boozman, John        Sale   1001.0     R
# 2573   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
# 2574   FISV 2020-01-02      Boozman, John        Sale   1001.0     R
# 2575   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                   Range
# 0      $1,001 - $15,000
# 1      $1,001 - $15,000
# 2      $1,001 - $15,000
# 3      $1,001 - $15,000
# ...

# %%
senate_rep = senate_party_df[senate_party_df["Party"]=="R"]
display(senate_rep)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 5      PYPL 2022-04-29  Tuberville, Tommy        Sale   50001.0     R
# 6      PYPL 2022-04-28  Tuberville, Tommy    Purchase    1001.0     R
# 7      PYPL 2022-04-28  Tuberville, Tommy        Sale   50001.0     R
# 8      LMND 2022-04-22      Hagerty, Bill        Sale    1001.0     R
# 9      ECOM 2022-04-21  Tuberville, Tommy    Purchase  100001.0     R
# ...     ...        ...                ...         ...       ...   ...
# 2571     GD 2020-01-04      Boozman, John        Sale    1001.0     R
# 2572   FBHS 2020-01-03      Boozman, John        Sale    1001.0     R
# 2573   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
# 2574   FISV 2020-01-02      Boozman, John        Sale    1001.0     R
# 2575   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
#
#                     Range
# 5      $50,001 - $100,000
# 6        $1,001 - $15,000
# 7      $50,001 - $100,000
# ...

# %%
senate_dem = senate_party_df[senate_party_df["Party"]=="D"]
display(senate_dem)
# Out:
#      Ticker       Date              Senator Transaction     Amount Party  \
# 0     ABYIX 2022-05-23    Carper, Thomas R.    Purchase     1001.0     D
# 1     GSMYX 2022-05-16    Carper, Thomas R.        Sale     1001.0     D
# 2       JCI 2022-05-16    Carper, Thomas R.        Sale     1001.0     D
# 3     FCPIX 2022-05-16    Carper, Thomas R.        Sale     1001.0     D
# 12        T 2022-04-11  Whitehouse, Sheldon        Sale     1001.0     D
# ...     ...        ...                  ...         ...        ...   ...
# 2303   BSTZ 2020-02-22    Carper, Thomas R.        Sale     1001.0     D
# 2357   ALLO 2020-02-18    Feinstein, Dianne        Sale  1000001.0     D
# 2369    DLR 2020-02-13  Whitehouse, Sheldon    Purchase    15001.0     D
# 2370     WM 2020-02-13  Whitehouse, Sheldon        Sale    15001.0     D
# 2470   ALLO 2020-01-31    Feinstein, Dianne        Sale   500001.0     D
#
#                       Range
# 0          $1,001 - $15,000
# 1          $1,001 - $15,000
# ...

# %%
senate_rep_aapl = senate_rep[senate_rep["Ticker"]=="AAPL"]
display(senate_rep_aapl)
# Out:
#      Ticker       Date                Senator Transaction    Amount Party  \
# 83     AAPL 2022-02-24  Capito, Shelley Moore        Sale    1001.0     R
# 219    AAPL 2022-01-14      Tuberville, Tommy        Sale   15001.0     R
# 290    AAPL 2021-12-22      Tuberville, Tommy        Sale   50001.0     R
# 297    AAPL 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 322    AAPL 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 346    AAPL 2021-11-22      Tuberville, Tommy    Purchase    1001.0     R
# 450    AAPL 2021-08-25  Capito, Shelley Moore    Purchase    1001.0     R
# 453    AAPL 2021-08-17  Capito, Shelley Moore        Sale    1001.0     R
# 521    AAPL 2021-06-23      Tuberville, Tommy        Sale    1001.0     R
# 523    AAPL 2021-06-23  Capito, Shelley Moore    Purchase    1001.0     R
# 804    AAPL 2020-12-22           Roberts, Pat    Purchase   15001.0     R
# 815    AAPL 2020-12-16           Roberts, Pat        Sale  100001.0     R
# ...

# %%
senate_dem_aapl = senate_dem[senate_dem["Ticker"]=="AAPL"]
display(senate_dem_aapl)
# Out:
#      Ticker       Date             Senator Transaction    Amount Party  \
# 84     AAPL 2022-02-24          Wyden, Ron    Purchase   50001.0     D
# 85     AAPL 2022-02-24          Wyden, Ron        Sale   50001.0     D
# 207    AAPL 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 377    AAPL 2021-10-29  Hickenlooper, John        Sale  250001.0     D
# 431    AAPL 2021-09-28   Carper, Thomas R.        Sale   15001.0     D
# 726    AAPL 2021-01-27          Wyden, Ron    Purchase    1001.0     D
# 729    AAPL 2021-01-27          Wyden, Ron    Purchase    1001.0     D
# 737    AAPL 2021-01-27          Wyden, Ron    Purchase    1001.0     D
# 748    AAPL 2021-01-20          Wyden, Ron    Purchase    1001.0     D
# 749    AAPL 2021-01-20          Wyden, Ron    Purchase    1001.0     D
# 750    AAPL 2021-01-20          Wyden, Ron    Purchase    1001.0     D
# 837    AAPL 2020-11-20   Carper, Thomas R.        Sale   50001.0     D
# ...

# %%
senate_msft = senate_party_df[senate_party_df["Ticker"]=="MSFT"]
display(senate_msft)
# Out:
#      Ticker       Date                Senator Transaction    Amount Party  \
# 64     MSFT 2022-03-22      Tuberville, Tommy        Sale   15001.0     R
# 87     MSFT 2022-02-24  Capito, Shelley Moore        Sale    1001.0     R
# 111    MSFT 2022-02-01      Tuberville, Tommy        Sale   15001.0     R
# 215    MSFT 2022-01-14      Tuberville, Tommy        Sale   15001.0     R
# 298    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 307    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 328    MSFT 2021-12-17  Capito, Shelley Moore        Sale    1001.0     R
# 347    MSFT 2021-11-22      Tuberville, Tommy    Purchase    1001.0     R
# 372    MSFT 2021-11-01     Hickenlooper, John        Sale  250001.0     D
# 454    MSFT 2021-08-17  Capito, Shelley Moore        Sale    1001.0     R
# 472    MSFT 2021-07-26  Capito, Shelley Moore        Sale    1001.0     R
# 522    MSFT 2021-06-23      Tuberville, Tommy        Sale    1001.0     R
# ...

# %%
senate_rep_msft = senate_rep[senate_rep["Ticker"]=="MSFT"]
display(senate_rep_msft)
# Out:
#      Ticker       Date                Senator Transaction    Amount Party  \
# 64     MSFT 2022-03-22      Tuberville, Tommy        Sale   15001.0     R
# 87     MSFT 2022-02-24  Capito, Shelley Moore        Sale    1001.0     R
# 111    MSFT 2022-02-01      Tuberville, Tommy        Sale   15001.0     R
# 215    MSFT 2022-01-14      Tuberville, Tommy        Sale   15001.0     R
# 298    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 307    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 328    MSFT 2021-12-17  Capito, Shelley Moore        Sale    1001.0     R
# 347    MSFT 2021-11-22      Tuberville, Tommy    Purchase    1001.0     R
# 454    MSFT 2021-08-17  Capito, Shelley Moore        Sale    1001.0     R
# 472    MSFT 2021-07-26  Capito, Shelley Moore        Sale    1001.0     R
# 522    MSFT 2021-06-23      Tuberville, Tommy        Sale    1001.0     R
# 572    MSFT 2021-04-20      Tuberville, Tommy    Purchase    1001.0     R
# ...

# %%
senate_dem_msft = senate_dem[senate_dem["Ticker"]=="MSFT"]
display(senate_dem_msft)
# Out:
#      Ticker       Date             Senator Transaction    Amount Party  \
# 372    MSFT 2021-11-01  Hickenlooper, John        Sale  250001.0     D
# 1101   MSFT 2020-07-31          Wyden, Ron    Purchase   50001.0     D
# 1103   MSFT 2020-07-31          Wyden, Ron    Purchase   50001.0     D
# 1157   MSFT 2020-06-26          Wyden, Ron    Purchase   15001.0     D
# 1165   MSFT 2020-06-24          Wyden, Ron    Purchase   15001.0     D
# 1171   MSFT 2020-06-23          Wyden, Ron    Purchase   15001.0     D
# 1178   MSFT 2020-06-17          Wyden, Ron    Purchase   15001.0     D
# 1891   MSFT 2020-04-02   Carper, Thomas R.        Sale    1001.0     D
#
#                     Range
# 372   $250,001 - $500,000
# 1101   $50,001 - $100,000
# 1103   $50,001 - $100,000
# 1157    $15,001 - $50,000
# 1165    $15,001 - $50,000
# 1171    $15,001 - $50,000
# 1178    $15,001 - $50,000
# 1891     $1,001 - $15,000

# %%
senate_dd = senate_party_df[senate_party_df["Ticker"]=="DD"]
display(senate_dd)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 715      DD 2021-02-05  Carper, Thomas R.    Purchase    1001.0     D
# 716      DD 2021-02-05  Carper, Thomas R.        Sale    1001.0     D
# 724      DD 2021-01-27  Carper, Thomas R.        Sale   15001.0     D
# 798      DD 2020-12-30  Carper, Thomas R.        Sale    1001.0     D
# 833      DD 2020-11-20  Carper, Thomas R.        Sale    1001.0     D
# 1302     DD 2020-04-16      Perdue, David        Sale    1001.0     R
# 1352     DD 2020-04-16      Perdue, David        Sale    1001.0     R
# 1488     DD 2020-04-14    Loeffler, Kelly        Sale   15001.0     R
# 1534     DD 2020-04-14      Perdue, David        Sale   50001.0     R
# 1598     DD 2020-04-14      Perdue, David        Sale   50001.0     R
# 1770     DD 2020-04-07    Loeffler, Kelly        Sale  100001.0     R
# 1771     DD 2020-04-07    Loeffler, Kelly    Purchase   15001.0     R
# ...

# %%
senate_dem_dd= senate_dd[senate_dd["Party"]=="D"]
display(senate_dem_dd)
# Out:
#     Ticker       Date            Senator Transaction   Amount Party  \
# 715     DD 2021-02-05  Carper, Thomas R.    Purchase   1001.0     D
# 716     DD 2021-02-05  Carper, Thomas R.        Sale   1001.0     D
# 724     DD 2021-01-27  Carper, Thomas R.        Sale  15001.0     D
# 798     DD 2020-12-30  Carper, Thomas R.        Sale   1001.0     D
# 833     DD 2020-11-20  Carper, Thomas R.        Sale   1001.0     D
#
#                  Range
# 715   $1,001 - $15,000
# 716   $1,001 - $15,000
# 724  $15,001 - $50,000
# 798   $1,001 - $15,000
# 833   $1,001 - $15,000

# %%
senate_rep_dd= senate_dd[senate_dd["Party"]=="R"]
display(senate_rep_dd)
# Out:
#      Ticker       Date          Senator Transaction    Amount Party  \
# 1302     DD 2020-04-16    Perdue, David        Sale    1001.0     R
# 1352     DD 2020-04-16    Perdue, David        Sale    1001.0     R
# 1488     DD 2020-04-14  Loeffler, Kelly        Sale   15001.0     R
# 1534     DD 2020-04-14    Perdue, David        Sale   50001.0     R
# 1598     DD 2020-04-14    Perdue, David        Sale   50001.0     R
# 1770     DD 2020-04-07  Loeffler, Kelly        Sale  100001.0     R
# 1771     DD 2020-04-07  Loeffler, Kelly    Purchase   15001.0     R
# 1772     DD 2020-04-07  Loeffler, Kelly    Purchase   15001.0     R
# 2067     DD 2020-03-10  Loeffler, Kelly    Purchase    1001.0     R
# 2069     DD 2020-03-09  Loeffler, Kelly    Purchase    1001.0     R
# 2143     DD 2020-03-03  Loeffler, Kelly    Purchase   50001.0     R
# 2153     DD 2020-03-02  Loeffler, Kelly    Purchase   15001.0     R
# 2156     DD 2020-03-02  Loeffler, Kelly    Purchase   50001.0     R
# ...

# %%
senate_nvda = senate_party_df[senate_party_df["Ticker"]=="NVDA"]
display(senate_nvda)
# Out:
#      Ticker       Date             Senator Transaction    Amount Party  \
# 124    NVDA 2022-01-31   Carper, Thomas R.    Purchase    1001.0     D
# 193    NVDA 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 255    NVDA 2022-01-06   Collins, Susan M.    Purchase   15001.0     R
# 375    NVDA 2021-11-01  Hickenlooper, John        Sale  500001.0     D
# 465    NVDA 2021-07-28   Tuberville, Tommy        Sale   15001.0     R
# 534    NVDA 2021-06-04   Carper, Thomas R.        Sale    1001.0     D
# 810    NVDA 2020-12-21        Roberts, Pat    Purchase   50001.0     R
# 892    NVDA 2020-11-11        Roberts, Pat        Sale   15001.0     R
# 897    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 898    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 900    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 916    NVDA 2020-09-14        Roberts, Pat    Purchase   15001.0     R
# ...

# %%
senate_dem_nvda= senate_nvda[senate_nvda["Party"]=="D"]
display(senate_dem_nvda)
# Out:
#      Ticker       Date             Senator Transaction    Amount Party  \
# 124    NVDA 2022-01-31   Carper, Thomas R.    Purchase    1001.0     D
# 193    NVDA 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 375    NVDA 2021-11-01  Hickenlooper, John        Sale  500001.0     D
# 534    NVDA 2021-06-04   Carper, Thomas R.        Sale    1001.0     D
# 897    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 898    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 900    NVDA 2020-10-16          Wyden, Ron    Purchase    1001.0     D
# 957    NVDA 2020-08-21          Wyden, Ron    Purchase   50001.0     D
# 975    NVDA 2020-08-21          Wyden, Ron    Purchase   50001.0     D
# 1019   NVDA 2020-08-19          Wyden, Ron    Purchase   15001.0     D
# 1035   NVDA 2020-08-19          Wyden, Ron    Purchase   15001.0     D
# 1105   NVDA 2020-07-30          Wyden, Ron    Purchase   50001.0     D
# ...

# %%
senate_rep_nvda= senate_nvda[senate_nvda["Party"]=="R"]
display(senate_rep_nvda)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 255    NVDA 2022-01-06  Collins, Susan M.    Purchase  15001.0     R
# 465    NVDA 2021-07-28  Tuberville, Tommy        Sale  15001.0     R
# 810    NVDA 2020-12-21       Roberts, Pat    Purchase  50001.0     R
# 892    NVDA 2020-11-11       Roberts, Pat        Sale  15001.0     R
# 916    NVDA 2020-09-14       Roberts, Pat    Purchase  15001.0     R
# 925    NVDA 2020-09-04       Roberts, Pat        Sale  15001.0     R
# 927    NVDA 2020-09-04       Roberts, Pat    Purchase  50001.0     R
# 930    NVDA 2020-09-04       Roberts, Pat        Sale  15001.0     R
# 931    NVDA 2020-09-04       Roberts, Pat        Sale  15001.0     R
# 1212   NVDA 2020-05-29       Roberts, Pat    Purchase  15001.0     R
# 1213   NVDA 2020-05-29       Roberts, Pat    Purchase  15001.0     R
# 1248   NVDA 2020-04-24       Roberts, Pat        Sale  50001.0     R
# 2104   NVDA 2020-03-06       Roberts, Pat    Purchase  50001.0     R
# ...

# %%
senate_dis = senate_party_df[senate_party_df["Ticker"]=="DIS"]
display(senate_dis)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 163     DIS 2022-01-18  Carper, Thomas R.    Purchase    1001.0     D
# 607     DIS 2021-04-05   Duckworth, Tammy        Sale    1001.0     D
# 725     DIS 2021-01-27         Wyden, Ron    Purchase    1001.0     D
# 728     DIS 2021-01-27         Wyden, Ron    Purchase    1001.0     D
# 736     DIS 2021-01-27         Wyden, Ron    Purchase    1001.0     D
# 891     DIS 2020-11-16       Roberts, Pat    Purchase    1001.0     R
# 993     DIS 2020-08-21       Moran, Jerry        Sale    1001.0     R
# 1005    DIS 2020-08-21       Moran, Jerry        Sale    1001.0     R
# 1025    DIS 2020-08-19      Cassidy, Bill        Sale    1001.0     R
# 1029    DIS 2020-08-19      Cassidy, Bill        Sale    1001.0     R
# 1083    DIS 2020-08-04         Wyden, Ron    Purchase   15001.0     D
# 1084    DIS 2020-08-04         Wyden, Ron    Purchase   15001.0     D
# ...

# %%
senate_dem_dis= senate_dis[senate_dis["Party"]=="D"]
display(senate_dem_dis)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 163     DIS 2022-01-18  Carper, Thomas R.    Purchase   1001.0     D
# 607     DIS 2021-04-05   Duckworth, Tammy        Sale   1001.0     D
# 725     DIS 2021-01-27         Wyden, Ron    Purchase   1001.0     D
# 728     DIS 2021-01-27         Wyden, Ron    Purchase   1001.0     D
# 736     DIS 2021-01-27         Wyden, Ron    Purchase   1001.0     D
# 1083    DIS 2020-08-04         Wyden, Ron    Purchase  15001.0     D
# 1084    DIS 2020-08-04         Wyden, Ron    Purchase  15001.0     D
# 1161    DIS 2020-06-24         Wyden, Ron    Purchase  50001.0     D
# 1182    DIS 2020-06-12         Wyden, Ron    Purchase   1001.0     D
# 1184    DIS 2020-06-12         Wyden, Ron    Purchase  50001.0     D
# 1185    DIS 2020-06-12         Wyden, Ron    Purchase   1001.0     D
# 1186    DIS 2020-06-12         Wyden, Ron    Purchase   1001.0     D
# 1265    DIS 2020-04-17         Wyden, Ron    Purchase  50001.0     D
# ...

# %%
senate_rep_dis= senate_dis[senate_dis["Party"]=="R"]
display(senate_rep_dis)
# Out:
#      Ticker       Date          Senator Transaction    Amount Party  \
# 891     DIS 2020-11-16     Roberts, Pat    Purchase    1001.0     R
# 993     DIS 2020-08-21     Moran, Jerry        Sale    1001.0     R
# 1005    DIS 2020-08-21     Moran, Jerry        Sale    1001.0     R
# 1025    DIS 2020-08-19    Cassidy, Bill        Sale    1001.0     R
# 1029    DIS 2020-08-19    Cassidy, Bill        Sale    1001.0     R
# 1349    DIS 2020-04-16    Perdue, David        Sale    1001.0     R
# 1353    DIS 2020-04-16    Perdue, David        Sale    1001.0     R
# 1428    DIS 2020-04-14    Perdue, David        Sale   15001.0     R
# 1464    DIS 2020-04-14    Perdue, David        Sale   15001.0     R
# 1473    DIS 2020-04-14    Perdue, David        Sale   15001.0     R
# 1518    DIS 2020-04-14    Perdue, David        Sale   15001.0     R
# 1525    DIS 2020-04-14    Perdue, David        Sale  100001.0     R
# 1580    DIS 2020-04-14    Perdue, David        Sale   15001.0     R
# ...

# %%
senate_gme = senate_party_df[senate_party_df["Ticker"]=="GME"]
display(senate_gme)
# Out:
#     Ticker       Date      Senator Transaction  Amount Party             Range
# 723    GME 2021-01-28  Toomey, Pat        Sale  1001.0     R  $1,001 - $15,000
# 733    GME 2021-01-27  Toomey, Pat    Purchase  1001.0     R  $1,001 - $15,000

# %%
def senate_trading_def(ticker=""):
        if len(ticker)>0:
            url = "https://api.quiverquant.com/beta/historical/senatetrading/"+ticker
        else:
            url = "https://api.quiverquant.com/beta/live/senatetrading"
        
        headers = {'accept': 'application/json',
'X-CSRFToken': 'TyTJwjuEC7VV7mOqZ622haRaaUr0x0Ng4nrwSRFKQs7vdoBcJlK9qjAS69ghzhFu',
'Authorization': 'Token c28eacfdf71675aa0dcad7feaa75eedfff51c547'}
        r = requests.get(url, headers=headers)
        j = json.loads(r.content)
        df = pd.DataFrame.from_dict(j)
        return df

# %%
senate_aapl = senate_trading_def("AAPL")

senate_aapl['Date'] = pd.to_datetime(senate_aapl['Date'])

senate_aapl = senate_aapl[(senate_aapl['Date'] > '2020-01-01') & (senate_aapl['Date'] <= '2022-06-03')]

display(senate_rep_aapl.groupby(['Date', 'Senator']).sum())

display(senate_dem_aapl.groupby(['Date', 'Senator']).sum())
# Out:
#                                     Amount
# Date       Senator
# 2020-01-10 Perdue, David            1001.0
# 2020-01-27 Inhofe, James M.        15001.0
# 2020-01-28 Perdue, David            1001.0
# 2020-02-11 Perdue, David            2002.0
# 2020-03-02 Roberts, Pat            15001.0
# 2020-03-06 Roberts, Pat            15001.0
# 2020-03-09 Cassidy, Bill            1001.0
# 2020-03-20 Roberts, Pat            15001.0
# 2020-03-24 Roberts, Pat            15001.0
# 2020-04-07 Loeffler, Kelly        250001.0
# 2020-04-08 Roberts, Pat             2002.0
# 2020-04-14 Perdue, David          160006.0
# 2020-04-16 Perdue, David           30002.0
# 2020-04-27 Roberts, Pat            15001.0
# 2020-05-29 Roberts, Pat            15001.0
# 2020-07-15 Inhofe, James M.        15001.0
# 2020-07-31 Roberts, Pat            50001.0
# 2020-08-03 Roberts, Pat            50001.0
# 2020-08-19 Cassidy, Bill            2002.0
# 2020-08-21 Moran, Jerry             2002.0
# ...

# %%
aapl = yf.Ticker("AAPL")
aapl_hist = aapl.history(start="2020-01-01", end="2022-06-03")
display(aapl_hist)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2020-01-02   72.776226   73.847336   72.518279   73.785919  135480400
# 2020-01-03   72.999779   73.842413   72.840097   73.068565  146322800
# 2020-01-06   72.174337   73.690095   71.918842   73.650787  118387200
# 2020-01-07   73.660632   73.921038   73.080863   73.304420  108872000
# 2020-01-08   73.002236   74.790687   73.002236   74.483604  132079200
# ...                ...         ...         ...         ...        ...
# 2022-05-26  137.389999  144.339996  137.139999  143.779999   90601500
# 2022-05-27  145.389999  149.679993  145.259995  149.639999   90978500
# 2022-05-31  149.070007  150.660004  146.839996  148.839996  103718400
# 2022-06-01  149.899994  151.740005  147.679993  148.710007   74286600
# 2022-06-02  147.830002  151.270004  146.860001  151.210007   72348100
#
#             Dividends  Stock Splits
# Date
# 2020-01-02        0.0           0.0
# 2020-01-03        0.0           0.0
# ...

# %%
#aapl_hist = aapl_hist.reset_index()
aapl_line = aapl_hist.hvplot(x='Date', y='Close')

# %%
senate_rep_aapl_close = senate_rep_aapl.merge(aapl_hist, left_on='Date', right_on='Date')
senate_rep_aapl_close.set_index('Date')
senate_rep_aapl_close['Amount'] = senate_rep_aapl_close['Amount'].astype(float)

# %%
senate_rep_aapl_close.head()
# Out:
#   Ticker       Date                Senator Transaction   Amount Party  \
# 0   AAPL 2022-02-24  Capito, Shelley Moore        Sale   1001.0     R
# 1   AAPL 2022-01-14      Tuberville, Tommy        Sale  15001.0     R
# 2   AAPL 2021-12-22      Tuberville, Tommy        Sale  50001.0     R
# 3   AAPL 2021-12-21           Moran, Jerry        Sale   1001.0     R
# 4   AAPL 2021-12-21           Moran, Jerry        Sale   1001.0     R
#
#                 Range        Open        High         Low       Close  \
# 0    $1,001 - $15,000  152.356153  162.611090  151.777002  162.501251
# 1   $15,001 - $50,000  170.870932  173.304254  170.621616  172.596207
# 2  $50,001 - $100,000  172.566261  175.378548  171.678698  175.159149
# 3    $1,001 - $15,000  171.090310  172.725820  168.656988  172.516403
# 4    $1,001 - $15,000  171.090310  172.725820  168.656988  172.516403
#
#       Volume  Dividends  Stock Splits
# 0  141147500        0.0           0.0
# 1   80440800        0.0           0.0
# ...

# %%
senate_rep_aapl_close.hvplot.points(x='Date', y='Close')
# Out:
# :Points   [Date,Close]

# %%
aapl_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_rep_aapl_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10)
# Out:
# :Overlay
#    .Curve.I   :Curve   [Date]   (Close)
#    .Scatter.I :Scatter   [Date]   (Close,Senator)

# %%
senate_dem_aapl_close = senate_dem_aapl.merge(aapl_hist, left_on='Date', right_on='Date')
senate_dem_aapl_close.set_index('Date')
senate_dem_aapl_close['Amount'] = senate_dem_aapl_close['Amount'].astype(float)
senate_dem_aapl_close.head()
# Out:
#   Ticker       Date             Senator Transaction    Amount Party  \
# 0   AAPL 2022-02-24          Wyden, Ron    Purchase   50001.0     D
# 1   AAPL 2022-02-24          Wyden, Ron        Sale   50001.0     D
# 2   AAPL 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 3   AAPL 2021-10-29  Hickenlooper, John        Sale  250001.0     D
# 4   AAPL 2021-09-28   Carper, Thomas R.        Sale   15001.0     D
#
#                  Range        Open        High         Low       Close  \
# 0   $50,001 - $100,000  152.356153  162.611090  151.777002  162.501251
# 1   $50,001 - $100,000  152.356153  162.611090  151.777002  162.501251
# 2     $1,001 - $15,000  171.040454  172.067633  168.946212  169.335144
# 3  $250,001 - $500,000  146.603006  149.311608  145.796403  149.172195
# 4    $15,001 - $50,000  142.649627  144.143340  141.096167  141.315247
#
#       Volume  Dividends  Stock Splits
# 0  141147500        0.0           0.0
# 1  141147500        0.0           0.0
# ...

# %%
aapl_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_dem_aapl_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10)
# Out:
# :Overlay
#    .Curve.I   :Curve   [Date]   (Close)
#    .Scatter.I :Scatter   [Date]   (Close,Senator)

# %%
# Group republican AAPL transactions by purchases and sales
aapl_purchase_rep_df = senate_rep_aapl_close.groupby('Transaction').get_group('Purchase')
aapl_sale_rep_df = senate_rep_aapl_close.groupby('Transaction').get_group('Sale')

# %%
# Calculate average returns for republicans who invested in Apple
aapl_rep_gain_loss = (aapl_sale_rep_df["Close"].mean()-aapl_purchase_rep_df["Close"].mean())
aapl_rep_return = (aapl_rep_gain_loss / aapl_purchase_rep_df["Close"].mean()) * 100
print(f"The average return for Republicans who invested in Apple was{aapl_rep_return: .2f}%.")
# Out:
# The average return for Republicans who invested in Apple was 0.08%.

# %%
# Group democrat AAPL transactions by purchases and sales
aapl_purchase_dem_df = senate_dem_aapl_close.groupby('Transaction').get_group('Purchase')
aapl_sale_dem_df = senate_dem_aapl_close.groupby('Transaction').get_group('Sale')

# %%
# Calculate average returns for democrats who invested in AAPL
aapl_dem_gain_loss = (aapl_sale_dem_df["Close"].mean()-aapl_purchase_dem_df["Close"].mean())
aapl_dem_return = (aapl_dem_gain_loss / aapl_purchase_dem_df["Close"].mean()) * 100
print(f"The average return for Democrats who invested in Apple was {aapl_dem_return:.2f}%.")
# Out:
# The average return for Democrats who invested in Apple was 13.18%.

# %%
# Calculate average return for Apple
aapl_daily_return = aapl_hist['Close'].pct_change()*100
aapl_hist["Returns"] = aapl_daily_return
aapl_cumulative_return = aapl_hist["Returns"].mean()*100
print(f"The average return for Apple was {aapl_cumulative_return:.2f}%.")
# Out:
# The average return for Apple was 14.52%.

# %%
#MSFT CODE
senate_msft = senate_trading_def("MSFT")
senate_msft['Date'] = pd.to_datetime(senate_msft['Date'])
senate_msft = senate_msft[(senate_msft['Date'] > '2020-01-01') & (senate_msft['Date'] <= '2022-06-03')]
display(senate_rep_msft.groupby(['Date', 'Senator']).sum())
display(senate_dem_msft.groupby(['Date', 'Senator']).sum())
# Out:
#                                     Amount
# Date       Senator
# 2020-02-11 Roberts, Pat            15001.0
# 2020-03-03 Capito, Shelley Moore    1001.0
# 2020-03-09 Cassidy, Bill            1001.0
# 2020-03-19 Loeffler, Kelly         15001.0
# 2020-03-24 Roberts, Pat             1001.0
# 2020-03-26 Roberts, Pat             1001.0
# 2020-04-07 Loeffler, Kelly        250001.0
# 2020-04-13 Inhofe, James M.        50001.0
# 2020-04-14 Perdue, David           30002.0
# 2020-04-16 Perdue, David          100002.0
# 2020-04-28 Roberts, Pat            15001.0
# 2020-04-29 Roberts, Pat            15001.0
# 2020-08-19 Cassidy, Bill            2002.0
# 2020-09-03 Roberts, Pat            15001.0
# 2020-09-04 Roberts, Pat            50001.0
# 2021-02-03 Tuberville, Tommy        1001.0
# 2021-04-20 Tuberville, Tommy        1001.0
# 2021-06-23 Tuberville, Tommy        1001.0
# 2021-07-26 Capito, Shelley Moore    1001.0
# 2021-08-17 Capito, Shelley Moore    1001.0
# ...

# %%
#get Ticker chart
msft = yf.Ticker("MSFT")
msft_hist = msft.history(start="2020-01-01", end="2022-06-03")
msft_hist.drop(columns=["Open", "High", "Low", "Volume", "Dividends", "Stock Splits"])
# Out:
#                  Close
# Date
# 2020-01-02  156.924393
# 2020-01-03  154.970383
# 2020-01-06  155.370972
# 2020-01-07  153.954315
# 2020-01-08  156.406586
# ...                ...
# 2022-05-26  265.899994
# 2022-05-27  273.239990
# 2022-05-31  271.869995
# 2022-06-01  272.420013
# 2022-06-02  274.579987
#
# [610 rows x 1 columns]

# %%
#msft_hist = msft_hist.reset_index()
msft_line = msft_hist.hvplot(x='Date', y='Close')
#republican party!!!!
senate_rep_msft_close = senate_rep_msft.merge(msft_hist, left_on='Date', right_on='Date')
senate_rep_msft_close.set_index('Date')
senate_rep_msft_close['Amount'] = senate_rep_msft_close['Amount'].astype(float)
senate_rep_msft_close = senate_rep_msft_close.drop(columns=['Range','Open','High','Low','Volume','Dividends','Stock Splits'])
display(senate_rep_msft_close)
#democrat Party
senate_dem_msft_close = senate_dem_msft.merge(msft_hist, left_on='Date', right_on='Date')
senate_dem_msft_close.set_index('Date')
senate_dem_msft_close['Amount'] = senate_dem_msft_close['Amount'].astype(float)
senate_dem_msft_close = senate_dem_msft_close.drop(columns=['Range','Open','High','Low','Volume','Dividends','Stock Splits'])
display(senate_dem_msft_close)
#display senate buys
display(senate_rep_msft_close.hvplot.points(x='Date', y='Close'))
display(senate_dem_msft_close.hvplot.points(x='Date', y='Close'))
#combined chart with senate buys via scatter
display(msft_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_rep_msft_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
display(msft_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_dem_msft_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
# Out:
#    Ticker       Date                Senator Transaction    Amount Party  \
# 0    MSFT 2022-03-22      Tuberville, Tommy        Sale   15001.0     R
# 1    MSFT 2022-02-24  Capito, Shelley Moore        Sale    1001.0     R
# 2    MSFT 2022-02-01      Tuberville, Tommy        Sale   15001.0     R
# 3    MSFT 2022-01-14      Tuberville, Tommy        Sale   15001.0     R
# 4    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 5    MSFT 2021-12-21           Moran, Jerry        Sale    1001.0     R
# 6    MSFT 2021-12-17  Capito, Shelley Moore        Sale    1001.0     R
# 7    MSFT 2021-11-22      Tuberville, Tommy    Purchase    1001.0     R
# 8    MSFT 2021-08-17  Capito, Shelley Moore        Sale    1001.0     R
# 9    MSFT 2021-07-26  Capito, Shelley Moore        Sale    1001.0     R
# 10   MSFT 2021-06-23      Tuberville, Tommy        Sale    1001.0     R
# 11   MSFT 2021-04-20      Tuberville, Tommy    Purchase    1001.0     R
# ...

# %%
# Group republican MSFT transactions by purchases and sales
msft_purchase_rep_df = senate_rep_msft_close.groupby('Transaction').get_group('Purchase')
msft_sale_rep_df = senate_rep_msft_close.groupby('Transaction').get_group('Sale')

# %%
# Calculate average returns for republicans who invested in Microsoft
msft_rep_gain_loss = (msft_sale_rep_df["Close"].mean()-msft_purchase_rep_df["Close"].mean())
msft_rep_return = (msft_rep_gain_loss / msft_purchase_rep_df["Close"].mean()) * 100
print(f"The average return for Republicans who invested in Microsoft was{msft_rep_return: .2f}%.")
# Out:
# The average return for Republicans who invested in Microsoft was 22.04%.

# %%
# Group democrat MSFT transactions by purchases and sales
msft_purchase_dem_df = senate_dem_msft_close.groupby('Transaction').get_group('Purchase')
msft_sale_dem_df = senate_dem_msft_close.groupby('Transaction').get_group('Sale')

# %%
# Calculate average returns for democrats who invested in Microsoft
msft_dem_gain_loss = (msft_sale_dem_df["Close"].mean()-msft_purchase_dem_df["Close"].mean())
msft_dem_return = (msft_dem_gain_loss / msft_purchase_dem_df["Close"].mean()) * 100
print(f"The average return for Democrats who invested in Microsoft was {msft_dem_return:.2f}%.")
# Out:
# The average return for Democrats who invested in Microsoft was 21.97%.

# %%
# Calculate average return for Microsoft
msft_daily_return = msft_hist['Close'].pct_change()*100
msft_hist["Returns"] = msft_daily_return
msft_cumulative_return = msft_hist["Returns"].mean()*100
print(f"The average return for Microsoft was {msft_cumulative_return:.2f}%.")
# Out:
# The average return for Microsoft was 11.56%.

# %%
#NVDA CODE
senate_nvda = senate_trading_def("NVDA")
senate_nvda['Date'] = pd.to_datetime(senate_nvda['Date'])
senate_nvda = senate_nvda[(senate_nvda['Date'] > '2020-01-01') & (senate_nvda['Date'] <= '2022-06-03')]
display(senate_rep_nvda.groupby(['Date', 'Senator']).sum())
display(senate_dem_nvda.groupby(['Date', 'Senator']).sum())
#get Ticker chart
nvda = yf.Ticker("NVDA")
nvda_hist = nvda.history(start="2020-01-01", end="2022-06-03")
nvda_hist.drop(columns=["Open", "High", "Low", "Volume", "Dividends", "Stock Splits"])

#nvda_hist = msft_hist.reset_index()
nvda_line = nvda_hist.hvplot(x='Date', y='Close')
#republican party!!!!
senate_rep_nvda_close = senate_rep_nvda.merge(nvda_hist, left_on='Date', right_on='Date')
senate_rep_nvda_close.set_index('Date')
senate_rep_nvda_close['Amount'] = senate_rep_nvda_close['Amount'].astype(float)
senate_rep_nvda_close = senate_rep_nvda_close.drop(columns=['Range','Open','High','Low','Volume','Dividends','Stock Splits'])
display(senate_rep_nvda_close)
#democrat Party
senate_dem_nvda_close = senate_dem_nvda.merge(nvda_hist, left_on='Date', right_on='Date')
senate_dem_nvda_close.set_index('Date')
senate_dem_nvda_close['Amount'] = senate_dem_nvda_close['Amount'].astype(float)
senate_dem_nvda_close = senate_dem_nvda_close.drop(columns=['Range','Open','High','Low','Volume','Dividends','Stock Splits'])
display(senate_dem_nvda_close)
#display senate buys
display(senate_rep_nvda_close.hvplot.points(x='Date', y='Close'))
display(senate_dem_nvda_close.hvplot.points(x='Date', y='Close'))
#combined chart with senate buys via scatter
display(nvda_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_rep_nvda_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
display(nvda_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_dem_nvda_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
# Out:
#                                Amount
# Date       Senator
# 2020-01-06 Roberts, Pat       15001.0
# 2020-02-11 Roberts, Pat       15001.0
# 2020-02-24 Loeffler, Kelly    30002.0
# 2020-02-26 Loeffler, Kelly    30002.0
# 2020-03-02 Roberts, Pat       15001.0
# 2020-03-06 Roberts, Pat       50001.0
# 2020-04-24 Roberts, Pat       50001.0
# 2020-05-29 Roberts, Pat       30002.0
# 2020-09-04 Roberts, Pat       95004.0
# 2020-09-14 Roberts, Pat       15001.0
# 2020-11-11 Roberts, Pat       15001.0
# 2020-12-21 Roberts, Pat       50001.0
# 2021-07-28 Tuberville, Tommy  15001.0
# 2022-01-06 Collins, Susan M.  15001.0
#                                  Amount
# Date       Senator
# 2020-04-21 Wyden, Ron           50001.0
# 2020-05-26 Wyden, Ron          100001.0
# 2020-06-12 Wyden, Ron           50001.0
# 2020-06-24 Wyden, Ron           15001.0
# 2020-06-26 Wyden, Ron           15001.0
# 2020-07-09 Carper, Thomas R.     1001.0
# 2020-07-30 Wyden, Ron          100002.0
# ...

# %%
#DD CODE
senate_dd = senate_trading_def("DD")
senate_dd['Date'] = pd.to_datetime(senate_dd['Date'])
senate_dd = senate_dd[(senate_dd['Date'] > '2020-01-01') & (senate_dd['Date'] <= '2022-06-03')]
display(senate_rep_dd.groupby(['Date', 'Senator']).sum())
display(senate_dem_dd.groupby(['Date', 'Senator']).sum())
#get Ticker chart
dd = yf.Ticker("DD")
dd_hist = dd.history(start="2020-01-01", end="2022-06-03")
display(dd_hist)

#dd_hist = dd_hist.reset_index()
dd_line = dd_hist.hvplot(x='Date', y='Close')
#republican party!!!!
senate_rep_dd_close = senate_rep_dd.merge(dd_hist, left_on='Date', right_on='Date')
senate_rep_dd_close.set_index('Date')
senate_rep_dd_close['Amount'] = senate_rep_dd_close['Amount'].astype(float)
display(senate_rep_dd_close)
#democrat Party
senate_dem_dd_close = senate_dem_dd.merge(dd_hist, left_on='Date', right_on='Date')
senate_dem_dd_close.set_index('Date')
senate_dem_dd_close['Amount'] = senate_dem_dd_close['Amount'].astype(float)
display(senate_dem_dd_close)
#display senate buys
display(senate_rep_dd_close.hvplot.points(x='Date', y='Close'))
display(senate_dem_dd_close.hvplot.points(x='Date', y='Close'))
#combined chart with senate buys via scatter
display(dd_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_rep_dd_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
display(dd_hist.hvplot(x='Date', y='Close', height=500, width=1000)*senate_dem_dd_close.hvplot.scatter(x='Date', y='Close', color='Senator').opts(size=10))
# Out:
#                               Amount
# Date       Senator
# 2020-01-24 Perdue, David     16002.0
# 2020-02-21 Loeffler, Kelly    2002.0
# 2020-02-26 Perdue, David      4004.0
# 2020-02-27 Loeffler, Kelly  100001.0
#            Perdue, David      6006.0
# 2020-02-28 Loeffler, Kelly  115002.0
#            Perdue, David      4004.0
# 2020-03-02 Loeffler, Kelly   65002.0
#            Perdue, David      1001.0
# 2020-03-03 Loeffler, Kelly   50001.0
# 2020-03-09 Loeffler, Kelly    1001.0
# 2020-03-10 Loeffler, Kelly    1001.0
# 2020-04-07 Loeffler, Kelly  130003.0
# 2020-04-14 Loeffler, Kelly   15001.0
#            Perdue, David    100002.0
# 2020-04-16 Perdue, David      2002.0
#                                Amount
# Date       Senator
# 2020-11-20 Carper, Thomas R.   1001.0
# 2020-12-30 Carper, Thomas R.   1001.0
# 2021-01-27 Carper, Thomas R.  15001.0
# 2021-02-05 Carper, Thomas R.   2002.0
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# ...

# %%
print(senate_dem_aapl_close.groupby('Transaction').get_group('Purchase'))
# Out:
#    Ticker       Date     Senator Transaction   Amount Party  \
# 0    AAPL 2022-02-24  Wyden, Ron    Purchase  50001.0     D
# 5    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 6    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 7    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 8    AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 9    AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 10   AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 12   AAPL 2020-09-02  Wyden, Ron    Purchase  50001.0     D
# 13   AAPL 2020-08-27  Wyden, Ron    Purchase  50001.0     D
# 14   AAPL 2020-08-07  Wyden, Ron    Purchase  50001.0     D
# 15   AAPL 2020-08-07  Wyden, Ron    Purchase  50001.0     D
# 17   AAPL 2020-06-26  Wyden, Ron    Purchase  15001.0     D
# 18   AAPL 2020-06-24  Wyden, Ron    Purchase  15001.0     D
# 19   AAPL 2020-06-23  Wyden, Ron    Purchase  50001.0     D
#
# ...

# %%
apple_purchase_dem_df=(senate_dem_aapl_close.groupby('Transaction').get_group('Purchase'))
display(apple_purchase_dem_df)
# Out:
#    Ticker       Date     Senator Transaction   Amount Party  \
# 0    AAPL 2022-02-24  Wyden, Ron    Purchase  50001.0     D
# 5    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 6    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 7    AAPL 2021-01-27  Wyden, Ron    Purchase   1001.0     D
# 8    AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 9    AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 10   AAPL 2021-01-20  Wyden, Ron    Purchase   1001.0     D
# 12   AAPL 2020-09-02  Wyden, Ron    Purchase  50001.0     D
# 13   AAPL 2020-08-27  Wyden, Ron    Purchase  50001.0     D
# 14   AAPL 2020-08-07  Wyden, Ron    Purchase  50001.0     D
# 15   AAPL 2020-08-07  Wyden, Ron    Purchase  50001.0     D
# 17   AAPL 2020-06-26  Wyden, Ron    Purchase  15001.0     D
# 18   AAPL 2020-06-24  Wyden, Ron    Purchase  15001.0     D
# 19   AAPL 2020-06-23  Wyden, Ron    Purchase  50001.0     D
#
# ...

# %%
print(senate_dem_aapl_close.groupby('Transaction').get_group('Sale'))
# Out:
#    Ticker       Date             Senator Transaction    Amount Party  \
# 1    AAPL 2022-02-24          Wyden, Ron        Sale   50001.0     D
# 2    AAPL 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 3    AAPL 2021-10-29  Hickenlooper, John        Sale  250001.0     D
# 4    AAPL 2021-09-28   Carper, Thomas R.        Sale   15001.0     D
# 11   AAPL 2020-11-20   Carper, Thomas R.        Sale   50001.0     D
# 16   AAPL 2020-07-09   Carper, Thomas R.        Sale    1001.0     D
#
#                   Range        Open        High         Low       Close  \
# 1    $50,001 - $100,000  152.356153  162.611090  151.777002  162.501251
# 2      $1,001 - $15,000  171.040454  172.067633  168.946212  169.335144
# 3   $250,001 - $500,000  146.603006  149.311608  145.796403  149.172195
# 4     $15,001 - $50,000  142.649627  144.143340  141.096167  141.315247
# 11   $50,001 - $100,000  117.590281  117.719128  116.252228  116.301781
# ...

# %%
apple_sale_dem_df=(senate_dem_aapl_close.groupby('Transaction').get_group('Sale'))
display(apple_sale_dem_df)
# Out:
#    Ticker       Date             Senator Transaction    Amount Party  \
# 1    AAPL 2022-02-24          Wyden, Ron        Sale   50001.0     D
# 2    AAPL 2022-01-18   Carper, Thomas R.        Sale    1001.0     D
# 3    AAPL 2021-10-29  Hickenlooper, John        Sale  250001.0     D
# 4    AAPL 2021-09-28   Carper, Thomas R.        Sale   15001.0     D
# 11   AAPL 2020-11-20   Carper, Thomas R.        Sale   50001.0     D
# 16   AAPL 2020-07-09   Carper, Thomas R.        Sale    1001.0     D
#
#                   Range        Open        High         Low       Close  \
# 1    $50,001 - $100,000  152.356153  162.611090  151.777002  162.501251
# 2      $1,001 - $15,000  171.040454  172.067633  168.946212  169.335144
# 3   $250,001 - $500,000  146.603006  149.311608  145.796403  149.172195
# 4     $15,001 - $50,000  142.649627  144.143340  141.096167  141.315247
# 11   $50,001 - $100,000  117.590281  117.719128  116.252228  116.301781
# ...

# %%
####
# 1) ron wyden bought 552.49 shares of apple on 6/23/2020. 
#       Amount/close = number of shares ()
#       $50,001/$90.50= 552.49
#   BOUGHT 552.49 shares at $90.50/avg
#
# ron wyden sold 307.698 shares of apple on 2/24/22. 
#       Amount/Close = number of shares
#       $50,001/$162.50 = 307.69 
#  SOLD 307.69 shares at $162.50/avg

#stock_return = (net return on investment/cost) * 100

# %%
list(apple_sale_dem_df.columns).dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4360/1497565630.py in <module>
# ----> 1 list(apple_sale_dem_df.columns).dtypes
#       2
#       3
#
# AttributeError: 'list' object has no attribute 'dtypes'

# %%
apple_sale_dem_df.dtypes

# %%
apple_sale_dem_df.iloc[0:16,[4]]

# %%
apple_sale_dem_df.iloc[0:16,[10]]

# %%
roi_df= ((apple_sale_dem_df.iloc[0:16,[4]])*(apple_sale_dem_df.iloc[0:16,[10]]))
display(roi_df)

# %%
roi = [apple_sale_dem_df / apple_purchase_dem_df]
roi["ROI"] = apple_sale_dem_df["Amount"]*apple_sale_dem_df["Close"]
roi.drop(columns=['Ticker','Party','Range','Open','High','Low']).sort_values("ROI").tail(10)
