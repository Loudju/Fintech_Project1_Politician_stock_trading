# %%
import quiverquant

# %%
quiver = quiverquant.quiver("c28eacfdf71675aa0dcad7feaa75eedfff51c547")

# %%
dfWSB = quiver.wallstreetbets()
# Out:
# https://api.quiverquant.com/beta/live/wallstreetbets?count_all=true
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\2787883138.py in <module>
# ----> 1 dfWSB = quiver.wallstreetbets()
#
# ~\anaconda3\envs\dev\lib\site-packages\quiverquant.py in wallstreetbets(self, ticker, date_from, date_to, yesterday)
#     138
#     139         if r.text == '"Upgrade your subscription plan to access this dataset."':
# --> 140             raise NameError('Upgrade your subscription plan to access this dataset.')
#     141
#     142         df = pd.DataFrame(json.loads(r.content))
#
# NameError: Upgrade your subscription plan to access this dataset.

# %%
display(dfCongress)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 0       IRT 2022-05-05        Thune, John        Sale  15001.0
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale  50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale  50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase   1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale   1001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale   1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale   1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                    Range
# 0      $15,001 - $50,000
# 1     $50,001 - $100,000
# 2     $50,001 - $100,000
# 3       $1,001 - $15,000
# 4       $1,001 - $15,000
# ...                  ...
# 2565      $1,001-$15,000
# 2566      $1,001-$15,000
# 2567    $1,001 - $15,000
# 2568      $1,001-$15,000
# 2569    $1,001 - $15,000
#
# [2570 rows x 7 columns]

# %%
dfparty = dfCongress
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\23127053.py in <module>
# ----> 1 dfparty = dfCongress('Party')
#
# TypeError: 'DataFrame' object is not callable

# %%
dfparty = dfCongress[dfCongress["Party"]=="R"]

# %%
display(dfparty)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale   50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale   50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase    1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale    1001.0     R
# 5      ECOM 2022-04-21  Tuberville, Tommy    Purchase  100001.0     R
# ...     ...        ...                ...         ...       ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale    1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale    1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale    1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
#
#                     Range
# 1      $50,001 - $100,000
# 2      $50,001 - $100,000
# 3        $1,001 - $15,000
# 4        $1,001 - $15,000
# 5     $100,001 - $250,000
# ...                   ...
# 2565       $1,001-$15,000
# 2566       $1,001-$15,000
# 2567     $1,001 - $15,000
# 2568       $1,001-$15,000
# 2569     $1,001 - $15,000
#
# [1864 rows x 7 columns]

# %%
dfparty.sort_values(by=['Transaction'])
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 815      BA 2020-12-07       Roberts, Pat    Purchase  15001.0     R
# 706    VEEV 2021-02-09  Tuberville, Tommy    Purchase   1001.0     R
# 1997    FHB 2020-03-17      Perdue, David    Purchase   1001.0     R
# 1998   NWSA 2020-03-17      Perdue, David    Purchase   1001.0     R
# 2280   AMZN 2020-02-24    Loeffler, Kelly    Purchase  15001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 1398    WFC 2020-04-14      Perdue, David        Sale  15001.0     R
# 1397    NKE 2020-04-14      Perdue, David        Sale  15001.0     R
# 1396    CVX 2020-04-14      Perdue, David        Sale  15001.0     R
# 1366   PAGP 2020-04-15      Perdue, David        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                   Range
# 815   $15,001 - $50,000
# 706    $1,001 - $15,000
# 1997   $1,001 - $15,000
# 1998   $1,001 - $15,000
# 2280  $15,001 - $50,000
# ...                 ...
# 1398  $15,001 - $50,000
# 1397  $15,001 - $50,000
# 1396  $15,001 - $50,000
# 1366   $1,001 - $15,000
# 2569   $1,001 - $15,000
#
# [1864 rows x 7 columns]

# %%
dfparty_dem = dfparty = dfCongress[dfCongress["Party"]=="D"]

# %%
display(dfparty_dem)
# Out:
#      Ticker       Date              Senator Transaction     Amount Party  \
# 8         T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 9         T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 10        T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 11      BDX 2022-04-01         Rosen, Jacky        Sale     1001.0     D
# 61     KWEB 2022-03-17    Carper, Thomas R.        Sale     1001.0     D
# ...     ...        ...                  ...         ...        ...   ...
# 2297   BSTZ 2020-02-22    Carper, Thomas R.        Sale     1001.0     D
# 2351   ALLO 2020-02-18    Feinstein, Dianne        Sale  1000001.0     D
# 2363    DLR 2020-02-13  Whitehouse, Sheldon    Purchase    15001.0     D
# 2364     WM 2020-02-13  Whitehouse, Sheldon        Sale    15001.0     D
# 2464   ALLO 2020-01-31    Feinstein, Dianne        Sale   500001.0     D
#
#                       Range
# 8          $1,001 - $15,000
# 9          $1,001 - $15,000
# 10         $1,001 - $15,000
# 11         $1,001 - $15,000
# 61         $1,001 - $15,000
# ...                     ...
# 2297       $1,001 - $15,000
# 2351  $1,000,001-$5,000,000
# 2363      $15,001 - $50,000
# 2364      $15,001 - $50,000
# 2464    $500,001-$1,000,000
#
# [698 rows x 7 columns]

# %%
dfparty_dem.sort_by("Date")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\2600613681.py in <module>
# ----> 1 dfparty_dem.sort_by("Date")
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_by'

# %%
import requests

# %%
url = "https://api.quiverquant.com/beta/historical/housetrading/AAPL"
headers = {'accept': 'application/json',
'X-CSRFToken': 'TyTJwjuEC7VV7mOqZ622haRaaUr0x0Ng4nrwSRFKQs7vdoBcJlK9qjAS69ghzhFu',
'Authorization': 'Token c28eacfdf71675aa0dcad7feaa75eedfff51c547'}
r = requests.get(url, headers=headers)
print(r.content)
# Out:
# b'[{"Date": "2022-05-11", "Ticker": "AAPL", "Representative": " Bob Gibbs", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2022-04-19", "Ticker": "AAPL", "Representative": " Josh Gottheimer", "Transaction": "Purchase", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2022-04-18", "Ticker": "AAPL", "Representative": " Debbie Dingell", "Transaction": "Sale", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2022-03-22", "Ticker": "AAPL", "Representative": " Kim Dr Schrier", "Transaction": "Sale", "Amount": 500001.0, "Range": "$500,001"}, {"Date": "2022-03-22", "Ticker": "AAPL", "Representative": " Kim Dr Schrier", "Transaction": "Sale", "Amount": 250001.0, "Range": "$250,001-$1,000,000"}, {"Date": "2022-03-15", "Ticker": "AAPL", "Representative": " Josh Gottheimer", "Transaction": "Sale", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2022-03-09", "Ticker": "AAPL", "Representative": " Josh Gottheimer", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2022-02-28", "Ticker": "AAPL", "Representative": " Donald Sternoff Beyer Jr.", "Transaction": "Sale", "Amount": 50001.0, "Range": "$50,001-$100,000"}, {"Date": "2022-02-23", "Ticker": "AAPL", "Representative": " Pete Sessions", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2022-01-28", "Ticker": "AAPL", "Representative": " Robert J. Wittman", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2022-01-21", "Ticker": "AAPL", "Representative": " Blake Moore", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2021-12-31", "Ticker": "AAPL", "Representative": " Marie Newman", "Transaction": "Sale", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2021-12-30", "Ticker": "AAPL", "Representative": " Nancy Pelosi", "Transaction": "Sale", "Amount": 500001.0, "Range": "$500,001"}, {"Date": "2021-12-30", "Ticker": "AAPL", "Representative": " Nancy Pelosi", "Transaction": "Sale", "Amount": 500001.0, "Range": "$500,001"}, {"Date": "2021-12-22", "Ticker": "AAPL", "Representative": " Bob Gibbs", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2021-12-14", "Ticker": "AAPL", "Representative": " Josh Gottheimer", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2021-12-01", "Ticker": "AAPL", "Representative": " Debbie Dingell", "Transaction": "Sale", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2021-11-26", "Ticker": "AAPL", "Representative": " Marie Newman", "Transaction": "Sale", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2021-11-18", "Ticker": "AAPL", "Representative": " Thomas Suozzi", "Transaction": "Sale", "Amount": 50001.0, "Range": "$50,001-$100,000"}, {"Date": "2021-11-15", "Ticker": "AAPL", "Representative": " Kim Dr Schrier", "Transaction": "Sale", "Amount": 250001.0, "Range": "$250,001-$1,000,000"}, {"Date": "2021-10-29", "Ticker": "AAPL", "Representative": " Marie Newman", "Transaction": "Purchase", "Amount": 15001.0, "Range": "$15,001-$50,000"}, {"Date": "2021-10-29", "Ticker": "AAPL", "Representative": " Josh Gottheimer", "Transaction": "Purchase", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2021-10-28", "Ticker": "AAPL", "Representative": " Kim Dr Schrier", "Transaction": "Purchase", "Amount": 250001.0, "Range": "$250,001-$1,000,000"}, {"Date": "2021-10-19", "Ticker": "AAPL", "Representative": " Thomas Suozzi", "Transaction": "Purchase", "Amount": 50001.0, "Range": "$50,001-$100,000"}, {"Date": "2021-09-10", "Ticker": "AAPL", "Representative": " Pete Sessions", "Transaction": "Sale", "Amount": 100001.0, "Range": "$100,001-250,000"}, {"Date": "2021-08-19", "Ticker": "AAPL", "Representative": " David B. Mckinley", "Transaction": "Sale", "Amount": 1001.0, "Range": "$1,001-$15,000"}, {"Date": "2021-08-13", "Ticker": "AAPL", "Representative": " Marie Newman", "Transaction": "Purcha ...

# %%
import yfinance as yf

# %%
twtr = yf.Ticker("TWTR")

# %%
period = "5y"

# %%
twtr_max = twtr.history(period)

# %%
twtr_max
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2017-06-01  18.219999  18.660000  18.200001  18.530001  13178600          0
# 2017-06-02  18.530001  18.580000  18.219999  18.309999   9383100          0
# 2017-06-05  18.290001  18.340000  18.020000  18.230000  10576500          0
# 2017-06-06  18.100000  18.150000  17.469999  17.570000  22811800          0
# 2017-06-07  17.620001  17.750000  17.299999  17.440001  15866200          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-05-24  36.939999  37.200001  35.400002  35.759998  22663000          0
# 2022-05-25  36.060001  37.369999  36.020000  37.160000  23262800          0
# 2022-05-26  38.520000  39.590000  38.230000  39.520000  22968400          0
# 2022-05-27  39.570000  40.770000  39.480000  40.169998  16768800          0
# 2022-05-31  40.070000  40.349998  39.419998  39.599998  10681196          0
#
#             Stock Splits
# Date
# 2017-06-01             0
# 2017-06-02             0
# 2017-06-05             0
# 2017-06-06             0
# 2017-06-07             0
# ...                  ...
# 2022-05-24             0
# 2022-05-25             0
# 2022-05-26             0
# 2022-05-27             0
# 2022-05-31             0
#
# [1259 rows x 7 columns]

# %%
twtr_5y = twtr_max.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'])

# %%
twtr_5y.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
