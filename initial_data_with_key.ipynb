# %%
import quiverquant
import pandas as pd
import json

# %%
quiver = quiverquant.quiver("c28eacfdf71675aa0dcad7feaa75eedfff51c547")

# %%
display(dfCongress)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 0       IRT 2022-05-05        Thune, John        Sale  15001.0
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale  50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale  50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase   1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale   1001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale   1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale   1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                    Range
# 0      $15,001 - $50,000
# 1     $50,001 - $100,000
# 2     $50,001 - $100,000
# 3       $1,001 - $15,000
# ...

# %%
dfparty = dfCongress
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\23127053.py in <module>
# ----> 1 dfparty = dfCongress('Party')
#
# TypeError: 'DataFrame' object is not callable

# %%
dfparty = dfCongress[dfCongress["Party"]=="R"]

# %%
display(dfparty)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale   50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale   50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase    1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale    1001.0     R
# 5      ECOM 2022-04-21  Tuberville, Tommy    Purchase  100001.0     R
# ...     ...        ...                ...         ...       ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale    1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale    1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale    1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
#
#                     Range
# 1      $50,001 - $100,000
# 2      $50,001 - $100,000
# 3        $1,001 - $15,000
# ...

# %%
dfparty.sort_values(by=['Transaction'])
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 815      BA 2020-12-07       Roberts, Pat    Purchase  15001.0     R
# 706    VEEV 2021-02-09  Tuberville, Tommy    Purchase   1001.0     R
# 1997    FHB 2020-03-17      Perdue, David    Purchase   1001.0     R
# 1998   NWSA 2020-03-17      Perdue, David    Purchase   1001.0     R
# 2280   AMZN 2020-02-24    Loeffler, Kelly    Purchase  15001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 1398    WFC 2020-04-14      Perdue, David        Sale  15001.0     R
# 1397    NKE 2020-04-14      Perdue, David        Sale  15001.0     R
# 1396    CVX 2020-04-14      Perdue, David        Sale  15001.0     R
# 1366   PAGP 2020-04-15      Perdue, David        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                   Range
# 815   $15,001 - $50,000
# 706    $1,001 - $15,000
# 1997   $1,001 - $15,000
# 1998   $1,001 - $15,000
# ...

# %%
dfparty_dem = dfparty = dfCongress[dfCongress["Party"]=="D"]

# %%
dfparty_dem_twtr = dfparty_dem[dfparty_dem["Ticker"]=="T"]

# %%
display(dfparty_dem_twtr)
# Out:
#      Ticker       Date              Senator Transaction   Amount Party  \
# 8         T 2022-04-08         Rosen, Jacky        Sale   1001.0     D
# 9         T 2022-04-08         Rosen, Jacky        Sale   1001.0     D
# 10        T 2022-04-08         Rosen, Jacky        Sale   1001.0     D
# 438       T 2021-08-30  Whitehouse, Sheldon        Sale  15001.0     D
# 957       T 2020-08-21           Wyden, Ron        Sale  50001.0     D
# 996       T 2020-08-21           Wyden, Ron        Sale  50001.0     D
# 1257      T 2020-04-17           Wyden, Ron    Purchase  15001.0     D
# 1798      T 2020-04-06           Wyden, Ron    Purchase   1001.0     D
#
#                    Range
# 8       $1,001 - $15,000
# 9       $1,001 - $15,000
# 10      $1,001 - $15,000
# 438    $15,001 - $50,000
# 957   $50,001 - $100,000
# 996   $50,001 - $100,000
# 1257   $15,001 - $50,000
# 1798    $1,001 - $15,000

# %%
import requests

# %%
url = "https://api.quiverquant.com/beta/live/senatetrading"
headers = {'accept': 'application/json',
'X-CSRFToken': 'TyTJwjuEC7VV7mOqZ622haRaaUr0x0Ng4nrwSRFKQs7vdoBcJlK9qjAS69ghzhFu',
'Authorization': 'Token c28eacfdf71675aa0dcad7feaa75eedfff51c547'}
r = requests.get(url, headers=headers)
dftrade = r.json()
display(dftrade)
# Out:
# [{'Ticker': 'IRT',
#   'Date': '2022-05-05',
#   'Senator': 'Thune, John',
#   'Transaction': 'Sale',
#   'Amount': 15001.0,
#   'Party': ' ',
#   'Range': '$15,001 - $50,000'},
#  {'Ticker': 'PYPL',
#   'Date': '2022-04-29',
#   'Senator': 'Tuberville, Tommy',
#   'Transaction': 'Sale',
#   'Amount': 50001.0,
#   'Party': 'R',
#   'Range': '$50,001 - $100,000'},
#  {'Ticker': 'PYPL',
#   'Date': '2022-04-28',
#   'Senator': 'Tuberville, Tommy',
#   'Transaction': 'Sale',
#   'Amount': 50001.0,
#   'Party': 'R',
#   'Range': '$50,001 - $100,000'},
#  {'Ticker': 'PYPL',
#   'Date': '2022-04-28',
#   'Senator': 'Tuberville, Tommy',
#   'Transaction': 'Purchase',
#   'Amount': 1001.0,
#   'Party': 'R',
#   'Range': '$1,001 - $15,000'},
#  {'Ticker': 'LMND',
#   'Date': '2022-04-22',
#   'Senator': 'Hagerty, Bill',
#   'Transaction': 'Sale',
#   'Amount': 1001.0,
#   'Party': 'R',
#   'Range': '$1,001 - $15,000'},
#  {'Ticker': 'ECOM',
#   'Date': '2022-04-21',
# ...

# %%
url = "https://api.quiverquant.com/beta/historical/senatetrading/aapl"
headers = {'accept': 'application/json',
'X-CSRFToken': 'TyTJwjuEC7VV7mOqZ622haRaaUr0x0Ng4nrwSRFKQs7vdoBcJlK9qjAS69ghzhFu',
'Authorization': 'Token c28eacfdf71675aa0dcad7feaa75eedfff51c547'}
r = requests.get(url, headers=headers)
dftrade = r.json()
display(dftrade)
# Out:
# [{'Date': '2022-02-24',
#   'Ticker': 'AAPL',
#   'Senator': 'Wyden, Ron',
#   'Transaction': 'Purchase',
#   'Amount': 50001.0,
#   'Range': '$50,001 - $100,000'},
#  {'Date': '2022-02-24',
#   'Ticker': 'AAPL',
#   'Senator': 'Wyden, Ron',
#   'Transaction': 'Sale',
#   'Amount': 50001.0,
#   'Range': '$50,001 - $100,000'},
#  {'Date': '2022-02-24',
#   'Ticker': 'AAPL',
#   'Senator': 'Capito, Shelley Moore',
#   'Transaction': 'Sale',
#   'Amount': 1001.0,
#   'Range': '$1,001 - $15,000'},
#  {'Date': '2022-01-18',
#   'Ticker': 'AAPL',
#   'Senator': 'Carper, Thomas R.',
#   'Transaction': 'Sale',
#   'Amount': 1001.0,
#   'Range': '$1,001 - $15,000'},
#  {'Date': '2022-01-14',
#   'Ticker': 'AAPL',
#   'Senator': 'Tuberville, Tommy',
#   'Transaction': 'Sale',
#   'Amount': 15001.0,
#   'Range': '$15,001 - $50,000'},
#  {'Date': '2021-12-22',
#   'Ticker': 'AAPL',
#   'Senator': 'Tuberville, Tommy',
#   'Transaction': 'Sale',
#   'Amount': 50001.0,
# ...

# %%
import yfinance as yf

# %%
twtr = yf.Ticker("TWTR")

# %%
period = "5y"

# %%
twtr_max = twtr.history(period)

# %%
twtr_max
# Out:
#                  Open       High        Low      Close    Volume  Dividends  \
# Date
# 2017-06-01  18.219999  18.660000  18.200001  18.530001  13178600          0
# 2017-06-02  18.530001  18.580000  18.219999  18.309999   9383100          0
# 2017-06-05  18.290001  18.340000  18.020000  18.230000  10576500          0
# 2017-06-06  18.100000  18.150000  17.469999  17.570000  22811800          0
# 2017-06-07  17.620001  17.750000  17.299999  17.440001  15866200          0
# ...               ...        ...        ...        ...       ...        ...
# 2022-05-24  36.939999  37.200001  35.400002  35.759998  22663000          0
# 2022-05-25  36.060001  37.369999  36.020000  37.160000  23262800          0
# 2022-05-26  38.520000  39.590000  38.230000  39.520000  22968400          0
# 2022-05-27  39.570000  40.770000  39.480000  40.169998  16768800          0
# 2022-05-31  40.070000  40.349998  39.419998  39.599998  10681196          0
#
#             Stock Splits
# Date
# ...

# %%
twtr_5y = twtr_max.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'])

# %%
twtr_5y.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfCongress_Tesla = quiver.senate_trading("NVDA")

# %%
display(dfCongress_Tesla)
# Out:
#          Date Ticker              Senator Transaction    Amount  \
# 0  2022-01-31   NVDA    Carper, Thomas R.    Purchase    1001.0
# 1  2022-01-18   NVDA    Carper, Thomas R.        Sale    1001.0
# 2  2022-01-06   NVDA    Collins, Susan M.    Purchase   15001.0
# 3  2021-11-01   NVDA   Hickenlooper, John        Sale  500001.0
# 4  2021-06-04   NVDA    Carper, Thomas R.        Sale    1001.0
# ..        ...    ...                  ...         ...       ...
# 59 2016-04-19   NVDA  Whitehouse, Sheldon    Purchase    1001.0
# 60 2016-01-06   NVDA  Whitehouse, Sheldon    Purchase    1001.0
# 61 2016-01-06   NVDA  Whitehouse, Sheldon    Purchase    1001.0
# 62 2016-01-05   NVDA  Whitehouse, Sheldon    Purchase    1001.0
# 63 2016-01-05   NVDA  Whitehouse, Sheldon    Purchase    1001.0
#
#                     Range
# 0        $1,001 - $15,000
# 1        $1,001 - $15,000
# 2       $15,001 - $50,000
# 3   $500,001 - $1,000,000
# 4        $1,001 - $15,000
# ..                    ...
# ...

# %%
dfsenate = quiver.senate_trading()

# %%
display(dfsenate)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 0       IRT 2022-05-05        Thune, John        Sale  15001.0
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale  50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale  50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase   1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale   1001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale   1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale   1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                    Range
# 0      $15,001 - $50,000
# 1     $50,001 - $100,000
# 2     $50,001 - $100,000
# 3       $1,001 - $15,000
# ...

# %%
dfsenate.groupby('Ticker').count().sort_values('Transaction')
# Out:
#         Date  Senator  Transaction  Amount  Party  Range
# Ticker
# IDXX       1        1            1       1      1      1
# DPZ        1        1            1       1      1      1
# DRI        1        1            1       1      1      1
# DTD        1        1            1       1      1      1
# DUK        1        1            1       1      1      1
# ...      ...      ...          ...     ...    ...    ...
# DIS       37       37           37      37     37     37
# NVDA      39       39           39      39     39     39
# MSFT      39       39           39      39     39     39
# DD        40       40           40      40     40     40
# AAPL      73       73           73      73     73     73
#
# [590 rows x 6 columns]

# %%
df_dd = quiver.senate_trading('MSFT')

# %%
display(df_dd)
# Out:
#          Date Ticker                Senator Transaction   Amount  \
# 0  2022-02-24   MSFT  Capito, Shelley Moore        Sale   1001.0
# 1  2022-01-14   MSFT      Tuberville, Tommy        Sale  15001.0
# 2  2021-12-21   MSFT           Moran, Jerry        Sale   1001.0
# 3  2021-12-21   MSFT           Moran, Jerry        Sale   1001.0
# 4  2021-12-17   MSFT  Capito, Shelley Moore        Sale   1001.0
# ..        ...    ...                    ...         ...      ...
# 94 2016-01-27   MSFT          Perdue, David        Sale   1001.0
# 95 2016-01-22   MSFT          Perdue, David        Sale   1001.0
# 96 2016-01-22   MSFT          Perdue, David        Sale   1001.0
# 97 2016-01-06   MSFT    Whitehouse, Sheldon    Purchase   1001.0
# 98 2016-01-06   MSFT    Whitehouse, Sheldon    Purchase   1001.0
#
#                 Range
# 0    $1,001 - $15,000
# 1   $15,001 - $50,000
# 2    $1,001 - $15,000
# 3    $1,001 - $15,000
# 4    $1,001 - $15,000
# ..                ...
# ...
