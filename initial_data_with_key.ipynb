# %%
import quiverquant

# %%
quiver = quiverquant.quiver("c28eacfdf71675aa0dcad7feaa75eedfff51c547")

# %%
dfWSB = quiver.wallstreetbets()
# Out:
# https://api.quiverquant.com/beta/live/wallstreetbets?count_all=true
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\2787883138.py in <module>
# ----> 1 dfWSB = quiver.wallstreetbets()
#
# ~\anaconda3\envs\dev\lib\site-packages\quiverquant.py in wallstreetbets(self, ticker, date_from, date_to, yesterday)
#     138
#     139         if r.text == '"Upgrade your subscription plan to access this dataset."':
# --> 140             raise NameError('Upgrade your subscription plan to access this dataset.')
#     141
#     142         df = pd.DataFrame(json.loads(r.content))
#
# NameError: Upgrade your subscription plan to access this dataset.

# %%
display(dfCongress)
# Out:
#      Ticker       Date            Senator Transaction   Amount Party  \
# 0       IRT 2022-05-05        Thune, John        Sale  15001.0
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale  50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale  50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase   1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale   1001.0     R
# ...     ...        ...                ...         ...      ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale   1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale   1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale   1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale   1001.0     R
#
#                    Range
# 0      $15,001 - $50,000
# 1     $50,001 - $100,000
# 2     $50,001 - $100,000
# 3       $1,001 - $15,000
# 4       $1,001 - $15,000
# ...                  ...
# 2565      $1,001-$15,000
# 2566      $1,001-$15,000
# 2567    $1,001 - $15,000
# 2568      $1,001-$15,000
# 2569    $1,001 - $15,000
#
# [2570 rows x 7 columns]

# %%
dfparty = dfCongress
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\23127053.py in <module>
# ----> 1 dfparty = dfCongress('Party')
#
# TypeError: 'DataFrame' object is not callable

# %%
dfparty = dfCongress[dfCongress["Party"]=="R"]

# %%
display(dfparty)
# Out:
#      Ticker       Date            Senator Transaction    Amount Party  \
# 1      PYPL 2022-04-29  Tuberville, Tommy        Sale   50001.0     R
# 2      PYPL 2022-04-28  Tuberville, Tommy        Sale   50001.0     R
# 3      PYPL 2022-04-28  Tuberville, Tommy    Purchase    1001.0     R
# 4      LMND 2022-04-22      Hagerty, Bill        Sale    1001.0     R
# 5      ECOM 2022-04-21  Tuberville, Tommy    Purchase  100001.0     R
# ...     ...        ...                ...         ...       ...   ...
# 2565     GD 2020-01-04      Boozman, John        Sale    1001.0     R
# 2566   FBHS 2020-01-03      Boozman, John        Sale    1001.0     R
# 2567   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
# 2568   FISV 2020-01-02      Boozman, John        Sale    1001.0     R
# 2569   ENTG 2020-01-02      Perdue, David        Sale    1001.0     R
#
#                     Range
# 1      $50,001 - $100,000
# 2      $50,001 - $100,000
# 3        $1,001 - $15,000
# 4        $1,001 - $15,000
# 5     $100,001 - $250,000
# ...                   ...
# 2565       $1,001-$15,000
# 2566       $1,001-$15,000
# 2567     $1,001 - $15,000
# 2568       $1,001-$15,000
# 2569     $1,001 - $15,000
#
# [1864 rows x 7 columns]

# %%
dfparty.sort_values(by=['Senator']).groupby('Transaction')

# %%
dfparty_dem = dfparty = dfCongress[dfCongress["Party"]=="D"]

# %%
display(dfparty_dem)
# Out:
#      Ticker       Date              Senator Transaction     Amount Party  \
# 8         T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 9         T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 10        T 2022-04-08         Rosen, Jacky        Sale     1001.0     D
# 11      BDX 2022-04-01         Rosen, Jacky        Sale     1001.0     D
# 61     KWEB 2022-03-17    Carper, Thomas R.        Sale     1001.0     D
# ...     ...        ...                  ...         ...        ...   ...
# 2297   BSTZ 2020-02-22    Carper, Thomas R.        Sale     1001.0     D
# 2351   ALLO 2020-02-18    Feinstein, Dianne        Sale  1000001.0     D
# 2363    DLR 2020-02-13  Whitehouse, Sheldon    Purchase    15001.0     D
# 2364     WM 2020-02-13  Whitehouse, Sheldon        Sale    15001.0     D
# 2464   ALLO 2020-01-31    Feinstein, Dianne        Sale   500001.0     D
#
#                       Range
# 8          $1,001 - $15,000
# 9          $1,001 - $15,000
# 10         $1,001 - $15,000
# 11         $1,001 - $15,000
# 61         $1,001 - $15,000
# ...                     ...
# 2297       $1,001 - $15,000
# 2351  $1,000,001-$5,000,000
# 2363      $15,001 - $50,000
# 2364      $15,001 - $50,000
# 2464    $500,001-$1,000,000
#
# [698 rows x 7 columns]

# %%
dfparty_dem.sort_by("Date")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7700\2600613681.py in <module>
# ----> 1 dfparty_dem.sort_by("Date")
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_by'
